# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# %%
df = pd.read_csv('/home/alcatraz/Documents/PycharmProjects/multihead_nn_tda_afm_analysis/data/1_layer/90_PE11_1/90_PE11_1.csv')
df = df.drop(df.columns[0], axis=1)
df.values
# Out:
# array([[ 3.4645,  7.2946,  7.8779, ...,  9.372 , 10.205 ,  9.2215],
#        [ 4.6003,  9.0326,  9.0137, ..., 10.608 , 11.04  , 11.361 ],
#        [ 4.933 ,  9.3653,  8.3426, ..., 10.941 , 12.075 , 12.095 ],
#        ...,
#        [17.376 , 13.376 , 12.052 , ...,  6.0178,  6.3489,  5.8673],
#        [17.307 , 12.605 , 12.887 , ...,  6.9528,  6.1797,  5.5977],
#        [16.435 , 12.636 , 11.312 , ...,  6.1813,  6.3117,  6.5327]])

# %%
image = Image.fromarray(df.values)

# %%
plt.imshow(image)
